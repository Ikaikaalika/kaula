# %% [markdown]
# # Demo Rollout\nSample rollout trajectories and render a GIF.

# %%
# !python training/rollout.py --checkpoint outputs/phase1_train/model_final.pt --horizon 8 --num-samples 4

# %%
# !python visualization/render_rollout.py --input outputs/rollout_sample.npz --output outputs/rollout_preview.gif
