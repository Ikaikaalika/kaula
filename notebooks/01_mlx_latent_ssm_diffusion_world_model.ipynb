# %% [markdown]
# # MLX latent diffusion + SSM world model starter
#
# Minimal notebook scaffold for Apple-silicon-first experiments.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd() if (Path.cwd() / 'src').exists() else Path.cwd().parent
sys.path.append(str(PROJECT_ROOT / 'src'))

# %%
import numpy as np
import matplotlib.pyplot as plt
import mlx.core as mx
from world_model.config import WorldModelConfig
from world_model.data import sample_moving_shapes_batch, set_seed
from world_model.train import build_alpha_bars, make_model_and_optimizer, train_epoch

# %%
cfg = WorldModelConfig()
set_seed(42)
alpha_bars = build_alpha_bars(cfg)
model, optimizer = make_model_and_optimizer(cfg)

# %%
frames, actions = sample_moving_shapes_batch(2, cfg.seq_len, cfg.image_size, cfg.channels)
print(frames.shape, actions.shape)

# %%
history = train_epoch(model, optimizer, cfg, alpha_bars, num_batches=10)
history[-1]
