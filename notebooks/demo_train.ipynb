# %% [markdown]
# # Demo Train\nPhase 1 toy training demo for latent state-space diffusion world model.

# %%
# !python training/train.py --model-config configs/model_small.yaml --diffusion-config configs/diffusion.yaml --training-config configs/training.yaml --max-steps 20
